# %% [markdown]
# # Default notebook
#
# This default notebook is executed using a Lakeflow job as defined in resources/sample_job.job.yml.

# %%
# Set default catalog and schema
# The value for 'catalog' is picked from the Databricks widget named "catalog"
catalog = dbutils.widgets.get("catalog")
schema = dbutils.widgets.get("schema")
spark.sql(f"USE CATALOG {catalog}")
spark.sql(f"CREATE SCHEMA IF NOT EXISTS {schema}")
spark.sql(f"USE SCHEMA {schema}")

# %%
spark.sql(f"""create or replace table {catalog}.{schema}.transactions_summary
select product,paymentMethod,
sum(quantity) as total_quantity,
sum(totalprice) as total_price
 from samples.bakehouse.sales_transactions group by product, paymentMethod""")
